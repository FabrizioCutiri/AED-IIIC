# %% [markdown]
# <a href="https://colab.research.google.com/github/FabrizioCutiri/AED-IIIC/blob/main/Tarea_Acad%C3%A9mica_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tarea Académica 01
#
# Alumnos:
# - Fabrizio Alexander Cutiri Agüero
# - Fredy Antonio Almeyda Alania
# - Yeni Fiorella Alvarado Mejía
# - Miguel Angel Orrego La Chira

# %% [markdown]
# **1. ¿CUÁLES SON LAS DIFERENCIAS ENTRE STRUCT Y CLASS?**
#
# La class es un tipo de dato de referencia, no almacena datos reales. La struct es un tipo de dato de tipo valor.

# %% [markdown]
# **2. ¿QUÉ SON LA HERENCIA TIPO PUBLICO Y PROTEGIDO?**
#
# La herencia tipo public, se toma directamente por la clase, es lo que se muestra en pantalla.
# la herencia tipo protected, valores establecidos para una o varias clases, se usa en la herencia de clases.

# %% [markdown]
# **3.¿PODEMOS UTILIZAR UNA FUNCIÓN SOBRESCRITA DE LA CLASE BASE EN LA CLASE DERIVADA?**
#
# sí, en la herencia de datos de una clase a otra

# %% [markdown]
# **4. ¿CÓMO SE CREA UNA CLASE ABSTRACTA?**
#
# crear una clase polimórfica, con encapsulamiento y demás

# %% [markdown]
# **5. ¿QUÉ PASA SI CREO UN OBJETO DE UNA CLASE ABSTRACTA, MUESTRA UN ERROR O COMPILA CON ÉXITO?**
#
# mostrará error, porque no puede crear objetos, ya que tiene métodos que no están definidos.

# %% [markdown]
# **6. ¿POR QUÉ CREAMOS EL DESTRUCTOR Y QUÉ HAY DENTRO DEL DESTRUCTOR?**
#
# para destruir datos ya almacenados, lo que hay dentro es cada valor inicializado en cero o espacio(vacío).

# %% [markdown]
# **7. ¿CÓMO SE ASIGNA LA MEMORIA EN C++?**
#
# Con la asignación de punteros y arreglos

# %% [markdown]
# **8. ¿HA UTILIZADO LA SOBRECARGA DE OPERADORES EN SU PROYECTO Y CÓMO?**
#
# En el conteo de vidas, tiempo del juego, número de aliados

# %% [markdown]
# **9. ¿DIFERENCIA ENTRE ENCAPSULAMIENTO Y ABSTRACCIÓN?**
#
# El encapsulamiento es lo que se dice que hacer al objeto y la abstracción es la ejecución de este

# %% [markdown]
# **10. CUANDO LA MISMA FUNCIÓN EXISTE TANTO EN LA CLASE BASE COMO EN LA CLASE DERIVADA, ¿ QUÉ FUNCIÓN ES EJECUTADA?**
#
# Se ejecuta la clase derivada, debido a que esta hereda todo de la clase base .

# %% [markdown]
# **11. ¿CÓMO PODEMOS UTILIZAR EL CONSTRUCTOR DE LA CLASE BASE CREANDO UN OBJETO DE LA CLASE DERIVADA?**
#
# Por la herencia de la clase base a la derivada

# %% [markdown]
# **12. ¿QUÉ ES LA HERENCIA Y CÓMO LO UTILIZÓ EN SU PROYECTO?**
#
# La herencia es la utilización de valores y atributos de una clase a otra, lo usé para el movimiento de figuras.

# %% [markdown]
# **13. ¿QUE ES NAMESPACE STD?**
#
# El motivo de using namespace std es el de dar acceso al espacio de nombres (namespace) std, donde se encuentra encerrada toda la librería estándar.

# %% [markdown]
# **14. ¿POR QUÉ CREAMOS UNA CLASE ABSTRACTA?**
#
# Es una clase que no está completamente especificada (posee métodos sin implementar), por lo tanto no se pueden crear instancias de la misma. Una clase abstracta se usa para servir de clase base a otras clases.

# %% [markdown]
# **15. ¿QUÉ ES LA MEMORIA TIPO PILA Y CÓMO FUNCIONA?**
#
# Una pila típica es un área de la memoria de los computadores con un origen fijo, un espacio para almacenar datos y un puntero. Al principio, su número de elementos es cero y la dirección del puntero coincide con la dirección de origen. Conforme van incorporándose datos, los elementos contenidos en la pila van incrementándose y el puntero va actualizando su dirección para hacerla coincidir con el último en incorporarse.

# %% [markdown]
# **16. ¿CÓMO HA UTILIZADO EL POLIMORFISMO EN SU TRABAJO FINAL DE CURSO?**
#
# Utilice la sobrecarga de funciones, lo cual permitía que una función pueda realizar muchas tareas.

# %% [markdown]
# **17. ¿QUÉ ES EL RETRASO EN LA VINCULACIÓN (LATE BINDING)?**
#
# Se refiere a lo que sucede normalmente cuando se usa una virtual keyword en la declaración de un método. Después se genera una tabla virtual, que es una tabla de búsqueda para dichas funciones que siempre se consultará cuando se las llame.

# %% [markdown]
# **18. ¿QUÉ ESTRUCTURA DE DATOS HA UTILIZADO EN SU TRABAJO FINAL DE CURSO ?**
#
# Utilice una estructura de datos de matriz, la cual es una estructura de datos que consta de una colección de elementos (valores o variables), cada uno identificado por al menos un índice o clave de matriz.

# %% [markdown]
# **19. ¿Por qué cerrar el archivo?¿Es necesario cerrarlo o se cerrará automáticamente al salir del programa?**
#
#   Antes que nada, hay que tener en cuenta que para trabajar con archivos de texto, ya sea crear, editar o leer, se necesita de una librería llamada “fstream”, la cual nos permite trabajar con estos archivos. Estos, son muy útiles ya que nos permiten guardar información, durante el tiempo de ejecución. Sin embargo, muchos, al momento de usarlo se olviden de finalizarlo haciendo uso de la función Close(). El uso de esta función es de suma importancia, ya que al terminar de usar el archivo, este se vuelve un recurso que ocupa el sistema y puede generar errores en tiempo de ejecución, al momento que querer volver a abrir el archivo

# %% [markdown]
# **20. ¿Qué es Object Slicing?**
#
#   La división de objetos ocurre cuando un objeto de clase derivada se asigna a un objeto de clase base, los atributos adicionales de un objeto de clase derivada se cortan para formar el objeto de clase base.

# %% [markdown]
# **21. ¿Qué objetos STL ha utilizado en su proyecto final y por qué?**
#
#   Los objetos STL que más he utilizado en mi proyecto final fueron los "vector". Estos me fueron de mucha ayuda al momento de generar los arreglos de los distintos enemigos en el juego.

# %% [markdown]
# **22. ¿Por qué escribimos el constructor?**
#
#   La razón por la cual al momento de codificar una clase, se escriba también su constructor es debido a que, mediante esta función nos permite asegurarnos de que la clase codificada siempre tenga valores válidos al momento de que se le instancie. Cabe recalcar que, el constructor es una función única de cada clase, ya que esta es llamada automáticamente al momento en que se declara a un objeto de esa clase.

# %% [markdown]
# **23. ¿Qué pasaría si no escribimos el constructor?**
#
#   Si por alguna razón olvidaste escribir el constructor de una clase, no te preocupes en que haya un error de compilación, ya que cuando no se declara un constructor de manera explícita para una clase, C++ se encarga de asignar un constructor implícito por defecto de la clase. Aunque, debes acostumbrarte a que cada vez que codifiques una clase, escribirle su respectivo constructor y destructor.

# %% [markdown]
# **24. ¿Puedo sobrecargar el destructor?¿Por qué?**
#
#   A diferencia de los constructores, los destructores no pueden ser sobrecargados, ya que como dice su nombre, esta función se encarga únicamente de eliminar un objeto determinado en una clase, lo cual no le permite retornar un valor o recibir parámetros, por ende no puede ser sobrecargado.

# %% [markdown]
# **25. ¿DIFERENCIA ENTRE TUPLA Y VECTOR?**
#
# Un vector es una secuencia ordenada de elementos que permite duplicados. Un conjunto es una colección de elementos que no está ordenada y no permite duplicados. Una tupla es una secuencia ordenada de elementos de una longitud determinada. Una tupla tiene propiedades que la distinguen de un conjunto.

# %% [markdown]
# **28. ¿Como hacer el manejo de Excepciones en C++?**
#
#   Las Excepciones son de mucha ayuda al momento de programar, ya que llama al programa para reconocer un error y tratar de controlarla. Para manejar las excepciones se debe hacer uso del try-catch, el cual es una condicional en la que si el programa llegará tener un error, notificará al programador sobre este, sin necesidad de pausar el programa, mediante un mensaje.
